# %%
import matplotlib.pyplot as plt
import numpy as np
import random as r

# %%
totals = []

for rep in range(100):
    for i in range(10):
        total = 0
        x = r.choice(range(1,7))
        total += x
    totals.append(total)
    
totals
# Out:
# [35,
#  72,
#  112,
#  149,
#  191,
#  223,
#  266,
#  299,
#  334,
#  363,
#  397,
#  429,
#  456,
#  497,
#  529,
#  568,
#  598,
#  636,
#  672,
#  703,
#  746,
#  775,
#  809,
#  845,
#  878,
#  901,
#  933,
#  969,
#  1003,
#  1038,
#  1071,
#  1110,
#  1145,
#  1178,
#  1211,
#  1247,
#  1281,
#  1321,
#  1353,
#  1380,
#  1419,
#  1454,
#  1500,
#  1540,
#  1582,
#  1617,
#  1648,
#  1689,
#  1724,
#  1762,
#  1803,
#  1845,
#  1883,
#  1921,
#  1960,
#  2002,
#  2046,
#  2081,
#  2116,
#  2146,
#  2174,
#  2209,
#  2245,
#  2277,
#  2313,
#  2352,
#  2382,
#  2412,
#  2449,
#  2477,
#  2507,
#  2544,
#  2578,
#  2616,
#  2663,
#  2698,
#  2742,
#  2774,
#  2801,
#  2834,
#  2863,
#  2897,
#  2925,
#  2966,
#  3003,
#  3033,
#  3073,
#  3113,
#  3141,
#  3170,
#  3215,
#  3246,
#  3273,
#  3317,
#  3347,
#  3388,
#  3430,
#  3460,
#  3502,
#  3539]
