# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %%
A1 = np.loadtxt("Village_Data_1.csv", delimiter=",")
A2 = np.loadtxt("Village_Data_2.csv", delimiter=",")

# %%
G1 = nx.to_networkx_graph(A1)
G2 = nx.to_networkx_graph(A2)

# %%
def basic_net_stats(G):
    print("Number of nodes: ", G.number_of_nodes())
    print("Number of edges: ", G.number_of_edges())
    print("Average degree: %.2f" % np.mean(list(dict(G.degree()).values())))

# %%
basic_net_stats(G1)
# Out:
# Number of nodes:  843
# Number of edges:  3405
# Average degree: 8.08

# %%
basic_net_stats(G2)
# Out:
# Number of nodes:  877
# Number of edges:  3063
# Average degree: 6.99

# %%
def plot_degree_distribution(G):
    plt.hist(list(dict(G.degree()).values()), histtype="step")
    plt.xlabel("Degree $k$")
    plt.ylabel("$P(k)$")
    plt.title("Degree Distribution")

# %%
plot_degree_distribution(G1)
plot_degree_distribution(G2)

# %%
def connected_component_subgraphs(G):
    for c in nx.connected_components(G):
        yield G.subgraph(c)

# %%
gen1 = connected_component_subgraphs(G1)
gen2 = connected_component_subgraphs(G2)

# %%
g = gen.__next__()

# %%
g.number_of_nodes()
# Out:
# 825

# %%
G1_LCC = max(gen1, key=len)

# %%
G2_LCC = max(gen2, key=len)

# %%
len(G2_LCC)
# Out:
# 810

# %%
G1_LCC.number_of_nodes() / G1.number_of_nodes()
# Out:
# 0.9786476868327402

# %%
G2_LCC.number_of_nodes() / G2.number_of_nodes()
# Out:
# 0.9236031927023945

# %%
plt.figure()
nx.draw(G1_LCC, node_color='lightblue', edge_color='grey', node_size=20)

# %%
plt.figure()
nx.draw(G2_LCC, node_color='lightblue', edge_color='grey', node_size=20)
